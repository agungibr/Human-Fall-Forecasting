# %% [markdown]
# <a href="https://colab.research.google.com/github/agungibr/Human-Fall-Forecasting/blob/main/studi_kasus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from apalah import *

hitung()
# Out:
# 50

# %%
bil_1 = input("Masukkan bilangan 1: ")
bil_2 = input("Masukkan bilangan 2: ")

print("Hasilnya adalah:", kurang(bil_1, bil_2))
# Out:
# Masukkan bilangan 1: 7
# Masukkan bilangan 2: 8
# Hasilnya adalah: -1

# %%
bil_1 = 7
bil_2 = 8

print(bil_1 + bil_2)
# Out:
# 15

# %%
# from apalah import *

# hitung()
# Out:
# 50

# %%
from apalah import hitung
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-791918382.py in <cell line: 0>()
#       1 from apalah import hitung
#       2
# ----> 3 tambah()
#
# TypeError: tambah() missing 2 required positional arguments: 'angka_1' and 'angka_2'
